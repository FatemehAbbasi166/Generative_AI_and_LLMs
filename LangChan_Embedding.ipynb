# %% [markdown]
# <a href="https://colab.research.google.com/github/FatemehAbbasi166/Generative_AI_and_LLMs/blob/main/LangChan_Embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.6/867.6 kB 5.8 MB/s eta 0:00:00
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/dataclasses-json/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 41.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
# ...

# %%
my_key = 'Your Open AI API Key'

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import openai
import sys

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
embedding = OpenAIEmbeddings()

# %%
sentence1 = "i like dogs"
sentence2 = "I work hard"
sentence3 = "the weather is ugly outside"

# %%
# !pip install tiktoken

# %%
embedding1 = embedding.embed_query(sentence1)

# %%
embedding1
# Out:
# [-0.027566197369154936,
#  -0.005426068614985327,
#  -0.025822780192241726,
#  -0.033049116706226137,
#  -0.027414594822710914,
#  0.022626516609664228,
#  -0.010403649545425773,
#  -0.008085410780801898,
#  0.0024556276992238873,
#  -0.019632387272151976,
#  0.0007264236102857558,
#  0.029208545560890437,
#  -0.005432385310143616,
#  0.0007449789896247183,
#  0.00018851481700464707,
#  0.014111567764131042,
#  0.029840218802009516,
#  -0.001223076211827909,
#  0.004162723064069712,
#  -0.003897420470437757,
#  -0.011742795438240855,
#  0.006872598791152595,
#  0.013012457218653488,
#  -0.04719858464130691,
#  -0.002316659707249621,
#  0.0046870115561753346,
#  0.016966727945515844,
#  -0.00018723173102466221,
#  -0.025898580534141194,
#  -0.016335056567041855,
#  0.026732388020325522,
#  0.0029972869865994857,
#  -0.015501248149534982,
#  -0.024812103378980214,
#  0.0059566738022492375,
#  -0.014995909742904228,
#  0.009677225411271086,
#  -0.011445909368817455,
# ...

# %%
len(embedding1)
# Out:
# 1536

# %%
embedding2 = embedding.embed_query(sentence2)
embedding3 = embedding.embed_query(sentence3)

# %%
len(embedding2)
# Out:
# 1536

# %%
import numpy as np

# %%
np.dot(embedding1,embedding1)
# Out:
# 0.9999999999999998

# %%
np.dot(embedding1,embedding2)
# Out:
# 0.8027200055956223
